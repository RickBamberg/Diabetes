# %%
# Passo 01
# Carregando as bibliotecas
#!pip install .....
#!pip uninstall bokeh
#!pip install bokeh==2.4.3

#!pip uninstall pandasgui
#!pip install pandasgui

# %%
# Passo 02
# A primeira coisa que temos que fazer é importar os pacotes que iremos utilizar.
# Obs.: Pacotes do Python são conjuntos de funcionalidades disponíveis da ferramenta.

#Pandas: Possui inúmeras funções e comandos para importar arquivos, analisar dados, tratar dados, etc.
import pandas as pd

# Pandasgui: Descrição graficas do dataframe
from pandasgui import show
import pandas as pd

#Matplotlib: Possui uma série de funções e comandos para exibição de gráficos
import matplotlib.pyplot as plt

#Seaborn: Possui uma série de funções e comandos para exibição de gráficos (Visualizações mais robustas do que o Matplotlib)
import seaborn as sns

#Numpy: Possui uma série de funções e comandos para trabalharmos com números de forma em geral(formatação, calculos, etc)
import numpy as np

# Biblioteca para fazer a PADRONIZAÇÃO
from sklearn.preprocessing import StandardScaler

# Biblioteca para fazer a PADRONIZAÇÃP ROBUST
from sklearn.preprocessing import RobustScaler

# Biblioteca para fazer a NORMALIZAÇÃO
from sklearn.preprocessing import MinMaxScaler

# Biblioteca para construção de modelos compostos com transformadores.
from sklearn.compose import ColumnTransformer

# Biblioteca para Balanciamento de dados
from imblearn.over_sampling import SMOTE

# Bilioteca para separação de dados em treino e teste
from sklearn.model_selection import train_test_split

# Biblioteca para calcular a acuracia do modelo
from sklearn.metrics import accuracy_score

# Algoritmo KNN
from sklearn.neighbors import KNeighborsClassifier

# Algoritmo SVM
from sklearn import svm

# Algoritmo SVC
from sklearn.svm import SVC

# Algoritmo LogisticRregression
from sklearn.linear_model import LogisticRegression

# Algoritmo RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# Algoritmo DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Algoritmo accurcy_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#Warnings: Possui detalhes sobre os avisos e alertas que aparecem, porém podemos utiliza-lo também para que os alertas de
#futuras atualizações e metodos depreciados não sejam exibidos
import warnings
warnings.filterwarnings("ignore") 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#pd.options.display.float_format = '{:.2f}'.format

# Locale: Utilizado para formatação de datas, valores, dias de acordo com a região que queremos.
import locale

# Comandos do sistema operacional
import os

# %%
#Comando utilizado para carregar o arquivo e armazena-lo como um DataFrame do Pandas
#Um DataFrame do Pandas é como se fosse uma planilha do Excel, onde podemos tratar linhas e colunas.

nome = 'Diabetes.csv'
df = pd.read_csv(nome)

# %%
# Ver as primeiras linhas

print("Primeiras linhas:")
display(df.head())
# Out:
# Primeiras linhas:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Ver as últimas linhas

print("\nÚltimas linhas:")
display(df.tail())
# Out:
# Últimas linhas:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# Obter informações gerais (tipos de dados, contagem de não nulos, uso de memória)

print("\nInformações do DataFrame:")
df.info()
# Out:
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Obter as dimensões (linhas, colunas)

print("\nShape (Linhas, Colunas):")
print(df.shape)
# Out:
# Shape (Linhas, Colunas):
# (768, 9)

# %%
# Listar os nomes das colunas

print("\nColunas:")
print(df.columns)
# Out:
# Colunas:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Avaliar se alguma variável possui valor nulo ou chamado de valores missing ou "NAN" (Not Available)

df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Verificando o número de valores únicos

df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# Mostrar as linhas duplicadas

display(df[df.duplicated(keep=False)]) # keep=False mostra todas as ocorrências de duplicatas
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Visualizando algumas medidas estatísticas

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Renomear uma coluna

df.rename(columns={"Pregnancies" : "Gravidez"}, inplace=True)
df.rename(columns={"Glucose" : "Glicose"}, inplace=True)	
df.rename(columns={"BloodPressure" : "Pressão arterial"}, inplace=True)
df.rename(columns={"SkinThickness" : "Espessura da pele"}, inplace=True)
df.rename(columns={"Insulin" : "Insulina"}, inplace=True)
df.rename(columns={"BMI" : "IMC"}, inplace=True)
df.rename(columns={"DiabetesPedigreeFunction" : "Diabetes Descendente"}, inplace=True) 
df.rename(columns={"Age" : "Idade"}, inplace=True)
df.rename(columns={"Outcome" : "Resultado"}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gravidez              768 non-null    int64
#  1   Glicose               768 non-null    int64
#  2   Pressão arterial      768 non-null    int64
#  3   Espessura da pele     768 non-null    int64
#  4   Insulina              768 non-null    int64
#  5   IMC                   768 non-null    float64
#  6   Diabetes Descendente  768 non-null    float64
#  7   Idade                 768 non-null    int64
#  8   Resultado             768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Gerando um BoxPlot de todas variaveis
plt.figure(figsize=(16,6))
ax = sns.boxplot(data = df)

# %%
# Lista das colunas onde zero é implausível e precisa ser tratado
colunas_para_imputar = ['Glicose', 'Pressão arterial', 'Espessura da pele', 'Insulina', 'IMC']
print("Valores médios ANTES da imputação (incluindo zeros onde aplicável):")
print(df[colunas_para_imputar].mean()) # Apenas para comparação depois

print("\nAntes - estatísticas descritivas (colunas selecionadas):")
print(df[colunas_para_imputar].describe())

print("-" * 30)

for coluna in colunas_para_imputar:
    # 1. Seleciona a coluna
    series_coluna = df[coluna]

    # 2. Calcula a mediana IGNORANDO os zeros
    #    (Criamos uma cópia temporária sem zeros para calcular a mediana)
    mediana_coluna = series_coluna[series_coluna > 0].median()

    # Verificação se a mediana foi calculada (caso todos os valores > 0 fossem NaN ou a coluna só tivesse 0)
    if pd.isna(mediana_coluna):
        # Se não puder calcular a mediana (ex: só tem zeros),
        # você pode usar a média geral (menos ideal) ou outra estratégia.
        # Mas para estas colunas, é quase certo que haverá valores > 0.
        print(f"Aviso: Não foi possível calcular a mediana não-zero para '{coluna}'. Pulando imputação.")
        continue # Pula para a próxima coluna

    print(f"Coluna: '{coluna}' - Mediana (sem zeros): {mediana_coluna:.2f}")

    # 3. Faz o replace dos zeros com a mediana calculada para ESSA coluna
    #    Usamos .loc para evitar SettingWithCopyWarning e garantir a modificação no df original
    df.loc[df[coluna] == 0, coluna] = mediana_coluna

    # Alternativa (funciona também, mas .loc é preferido):
    # df[coluna] = df[coluna].replace(0, mediana_coluna)

print("-" * 30)
print("Imputação concluída.")

# 4. Verificação Opcional: Contar zeros restantes e ver novas estatísticas
print("\nZeros restantes nas colunas imputadas:")
print((df[colunas_para_imputar] == 0).sum()) # Deve ser tudo zero

print("\nValores médios DEPOIS da imputação:")
print(df[colunas_para_imputar].mean()) # Compare com antes

print("\nNovas estatísticas descritivas (colunas selecionadas):")
print(df[colunas_para_imputar].describe())
# Out:
# Valores médios ANTES da imputação (incluindo zeros onde aplicável):
# Glicose              120.894531
# Pressão arterial      69.105469
# Espessura da pele     20.536458
# Insulina              79.799479
# IMC                   31.992578
# dtype: float64
#
# Antes - estatísticas descritivas (colunas selecionadas):
#           Glicose  Pressão arterial  Espessura da pele    Insulina         IMC
# count  768.000000        768.000000         768.000000  768.000000  768.000000
# mean   120.894531         69.105469          20.536458   79.799479   31.992578
# std     31.972618         19.355807          15.952218  115.244002    7.884160
# min      0.000000          0.000000           0.000000    0.000000    0.000000
# 25%     99.000000         62.000000           0.000000    0.000000   27.300000
# 50%    117.000000         72.000000          23.000000   30.500000   32.000000
# 75%    140.250000         80.000000          32.000000  127.250000   36.600000
# max    199.000000        122.000000          99.000000  846.000000   67.100000
# ------------------------------
# Coluna: 'Glicose' - Mediana (sem zeros): 117.00
# Coluna: 'Pressão arterial' - Mediana (sem zeros): 72.00
# Coluna: 'Espessura da pele' - Mediana (sem zeros): 29.00
# Coluna: 'Insulina' - Mediana (sem zeros): 125.00
# Coluna: 'IMC' - Mediana (sem zeros): 32.30
# ------------------------------
# Imputação concluída.
#
# Zeros restantes nas colunas imputadas:
# Glicose              0
# Pressão arterial     0
# Espessura da pele    0
# Insulina             0
# IMC                  0
# dtype: int64
#
# Valores médios DEPOIS da imputação:
# Glicose              121.656250
# Pressão arterial      72.386719
# Espessura da pele     29.108073
# Insulina             140.671875
# IMC                   32.455208
# dtype: float64
#
# Novas estatísticas descritivas (colunas selecionadas):
#           Glicose  Pressão arterial  Espessura da pele    Insulina         IMC
# count  768.000000        768.000000         768.000000  768.000000  768.000000
# mean   121.656250         72.386719          29.108073  140.671875   32.455208
# std     30.438286         12.096642           8.791221   86.383060    6.875177
# min     44.000000         24.000000           7.000000   14.000000   18.200000
# 25%     99.750000         64.000000          25.000000  121.500000   27.500000
# 50%    117.000000         72.000000          29.000000  125.000000   32.300000
# 75%    140.250000         80.000000          32.000000  127.250000   36.600000
# max    199.000000        122.000000          99.000000  846.000000   67.100000

# %%
# Gerando um BoxPlot de todas variaveis
plt.figure(figsize=(16,6))
ax = sns.boxplot(data = df)

# %%
# Verificando se a variável resposta está balanceada
target_count = df.Resultado.value_counts()
target_count
# Out:
# Resultado
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# Distribuição dos resultado antes do balanceamentos
# Tamanho da figura (opcional)
plt.figure(figsize=(6,4))

# Título
plt.title("Distribuição do Resultado (0 = Não, 1 = Sim)")

# Gráfico de contagem
sns.countplot(x='Resultado', data=df, palette='pastel')

# Rótulo dos eixos
plt.xlabel("Tem Diabetes")
plt.ylabel("Quantidade")

# Mostrar os valores no topo das barras (opcional)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Balanciamento dos dados -- No momento não está sendo usado no treino

# 1. Separar features e target
X = df.drop('Resultado', axis=1)
y = df['Resultado']

# 2. Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# 3. Balancear o treino
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

# %%
# Distribuição dos resultado após do balanceamentos
# Tamanho da figura (opcional)
plt.figure(figsize=(6,4))
plt.title("Distribuição do Resultado após Balanceamento")
sns.countplot(x=y_train_bal, palette='pastel')

plt.xlabel("Tem Diabetes (0 = Não, 1 = Sim)")
plt.ylabel("Quantidade")

# Mostrar os valores no topo das barras
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Criando um objeto para PADRONIZAÇÃO dos dados
x = df.drop('Resultado', axis=1)
y = df['Resultado']

obj_padronizacao = StandardScaler().fit(x)

# %%
# Aplicando a PADRONIZAÇÃO
df_padronizado = obj_padronizacao.transform(x)

# %%
df_padronizado
# Out:
# array([[ 0.63994726,  0.86604475, -0.03198993, ...,  0.16661938,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.20506583, -0.5283186 , ..., -0.85219976,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01666174, -0.69376149, ..., -1.33250021,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.02157407, -0.03198993, ..., -0.910418  ,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14279979, -1.02464727, ..., -0.34279019,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.94206766, -0.19743282, ..., -0.29912651,
#         -0.47378505, -0.87137393]])

# %%
# Depois junte novamente se quiser manter como DataFrame:
df_padronizado = pd.DataFrame(df_padronizado, columns=x.columns)
df_padronizado['Resultado'] = y.reset_index(drop=True)
df_padronizado.columns = ['Gravidez','Glicose','Pressão arterial','Espessura da pele','Insulina','IMC',
                      'Diabetes Descendente', 'Idade','Resultado']

# %%
# Observe que é criado um ARRAY dos dados
df_padronizado
# Out:
#      Gravidez   Glicose  Pressão arterial  Espessura da pele  Insulina  \
# 0    0.639947  0.866045         -0.031990           0.670643 -0.181541
# 1   -0.844885 -1.205066         -0.528319          -0.012301 -0.181541
# 2    1.233880  2.016662         -0.693761          -0.012301 -0.181541
# 3   -0.844885 -1.073567         -0.528319          -0.695245 -0.540642
# 4   -1.141852  0.504422         -2.679076           0.670643  0.316566
# 5    0.342981 -0.185948          0.133453          -0.012301 -0.181541
# 6   -0.250952 -1.435189         -1.851862           0.329171 -0.610145
# 7    1.827813 -0.218823         -0.031990          -0.012301 -0.181541
# 8   -0.547919  2.476909         -0.197433           1.808882  4.660524
# 9    1.233880  0.109925          1.953325          -0.012301 -0.181541
# 10   0.046014 -0.383197          1.622439          -0.012301 -0.181541
# 11   1.827813  1.523540          0.133453          -0.012301 -0.181541
# 12   1.827813  0.570172          0.629782          -0.012301 -0.181541
# 13  -0.844885  2.213910         -1.024647          -0.695245  8.170442
# 14   0.342981  1.457791         -0.031990          -1.150541  0.397653
# 15   0.936914 -0.711944         -0.031990          -0.012301 -0.181541
# 16  -1.141852 -0.120198          0.960667           2.036530  1.034767
# 17   0.936914 -0.481821          0.133453          -0.012301 -0.181541
# 767 -0.299127             -0.473785 -0.871374          0

# %%
# Transformando para DataFrame e nomeando as colunas
df_padronizado = pd.DataFrame(df_padronizado)
df_padronizado.columns = ['Gravidez','Glicose','Pressão arterial','Espessura da pele','Insulina','IMC',
                      'Diabetes Descendente', 'Idade','Resultado']

# Visualizando os dados padronizados
df_padronizado.head()
# Out:
#    Gravidez   Glicose  Pressão arterial  Espessura da pele  Insulina  \
# 0  0.639947  0.866045         -0.031990           0.670643 -0.181541
# 1 -0.844885 -1.205066         -0.528319          -0.012301 -0.181541
# 2  1.233880  2.016662         -0.693761          -0.012301 -0.181541
# 3 -0.844885 -1.073567         -0.528319          -0.695245 -0.540642
# 4 -1.141852  0.504422         -2.679076           0.670643  0.316566
#
#         IMC  Diabetes Descendente     Idade  Resultado
# 0  0.166619              0.468492  1.425995          1
# 1 -0.852200             -0.365061 -0.190672          0
# 2 -1.332500              0.604397 -0.105584          1
# 3 -0.633881             -0.920763 -1.041549          0
# 4  1.549303              5.484909 -0.020496          1

# %%
# Visualizando as medidas dos dados PADRONIZADOS
df_padronizado.describe()
# Out:
#            Gravidez       Glicose  Pressão arterial  Espessura da pele  \
# count  7.680000e+02  7.680000e+02      7.680000e+02       7.680000e+02
# mean  -6.476301e-17  4.625929e-18      5.782412e-18      -1.526557e-16
# std    1.000652e+00  1.000652e+00      1.000652e+00       1.000652e+00
# min   -1.141852e+00 -2.552931e+00     -4.002619e+00      -2.516429e+00
# 25%   -8.448851e-01 -7.201630e-01     -6.937615e-01      -4.675972e-01
# 50%   -2.509521e-01 -1.530732e-01     -3.198993e-02      -1.230129e-02
# 75%    6.399473e-01  6.112653e-01      6.297816e-01       3.291706e-01
# max    3.906578e+00  2.542658e+00      4.104082e+00       7.955377e+00
#
#            Insulina           IMC  Diabetes Descendente         Idade  \
# count  7.680000e+02  7.680000e+02          7.680000e+02  7.680000e+02
# mean   1.503427e-17  2.613650e-16          2.451743e-16  1.931325e-16
# std    1.000652e+00  1.000652e+00          1.000652e+00  1.000652e+00
# min   -1.467353e+00 -2.074783e+00         -1.189553e+00 -1.041549e+00
# 25%   -2.220849e-01 -7.212087e-01         -6.889685e-01 -7.862862e-01
# 50%   -1.815412e-01 -2.258989e-02         -3.001282e-01 -3.608474e-01
# 75%   -1.554775e-01  6.032562e-01          4.662269e-01  6.602056e-01
# max    8.170442e+00  5.042397e+00          5.883565e+00  4.063716e+00
#
#         Resultado
# count  768.000000
# mean     0.348958
# std      0.476951
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
# Gerando os BoxPlot dos dados Padronizados
plt.figure(figsize=(16,6))
ax = sns.boxplot(data = df_padronizado)

# %%
# Visualizando novamente o DataFrame Original
df.head()
# Out:
#    Gravidez  Glicose  Pressão arterial  Espessura da pele  Insulina   IMC  \
# 0         6      148                72                 35       125  33.6
# 1         1       85                66                 29       125  26.6
# 2         8      183                64                 29       125  23.3
# 3         1       89                66                 23        94  28.1
# 4         0      137                40                 35       168  43.1
#
#    Diabetes Descendente  Idade  Resultado
# 0                 0.627     50          1
# 1                 0.351     31          0
# 2                 0.672     32          1
# 3                 0.167     21          0
# 4                 2.288     33          1

# %%
# Criando um objeto para NORMALIZAR os dados
x = df.drop('Resultado', axis=1)
y = df['Resultado']

obj_normalizacao = MinMaxScaler().fit(x)

# %%
# Aplicando a NORMALIZAÇÃO
df_normalizado = obj_normalizacao.transform(x)

# %%
# Visualizando os dados normalizados
df_normalizado
# Out:
# array([[0.35294118, 0.67096774, 0.48979592, ..., 0.31492843, 0.23441503,
#         0.48333333],
#        [0.05882353, 0.26451613, 0.42857143, ..., 0.17177914, 0.11656704,
#         0.16666667],
#        [0.47058824, 0.89677419, 0.40816327, ..., 0.10429448, 0.25362938,
#         0.18333333],
#        ...,
#        [0.29411765, 0.49677419, 0.48979592, ..., 0.16359918, 0.07130658,
#         0.15      ],
#        [0.05882353, 0.52903226, 0.36734694, ..., 0.24335378, 0.11571307,
#         0.43333333],
#        [0.05882353, 0.31612903, 0.46938776, ..., 0.24948875, 0.10119556,
#         0.03333333]])

# %%
# Depois junte novamente se quiser manter como DataFrame:
df_normalizado = pd.DataFrame(df_normalizado, columns=x.columns)
df_normalizado['Resultado'] = y.reset_index(drop=True)
df_normalizado.columns = ['Gravidez','Glicose','Pressão arterial','Espessura da pele','Insulina','IMC',
                      'Diabetes Descendente', 'Idade','Resultado']

# Visualizando os dados NORMALIZADOS
df_normalizado.head()
# Out:
#    Gravidez   Glicose  Pressão arterial  Espessura da pele  Insulina  \
# 0  0.352941  0.670968          0.489796           0.304348  0.133413
# 1  0.058824  0.264516          0.428571           0.239130  0.133413
# 2  0.470588  0.896774          0.408163           0.239130  0.133413
# 3  0.058824  0.290323          0.428571           0.173913  0.096154
# 4  0.000000  0.600000          0.163265           0.304348  0.185096
#
#         IMC  Diabetes Descendente     Idade  Resultado
# 0  0.314928              0.234415  0.483333          1
# 1  0.171779              0.116567  0.166667          0
# 2  0.104294              0.253629  0.183333          1
# 3  0.202454              0.038002  0.000000          0
# 4  0.509202              0.943638  0.200000          1

# %%
# Visualizando as medidas dos dados normalizados
df_normalizado.describe()
# Out:
#          Gravidez     Glicose  Pressão arterial  Espessura da pele  \
# count  768.000000  768.000000        768.000000         768.000000
# mean     0.226180    0.501008          0.493742           0.240305
# std      0.198210    0.196376          0.123435           0.095557
# min      0.000000    0.000000          0.000000           0.000000
# 25%      0.058824    0.359677          0.408163           0.195652
# 50%      0.176471    0.470968          0.489796           0.239130
# 75%      0.352941    0.620968          0.571429           0.271739
# max      1.000000    1.000000          1.000000           1.000000
#
#          Insulina         IMC  Diabetes Descendente       Idade   Resultado
# count  768.000000  768.000000            768.000000  768.000000  768.000000
# mean     0.152250    0.291518              0.168179    0.204015    0.348958
# std      0.103826    0.140597              0.141473    0.196004    0.476951
# min      0.000000    0.000000              0.000000    0.000000    0.000000
# 25%      0.129207    0.190184              0.070773    0.050000    0.000000
# 50%      0.133413    0.288344              0.125747    0.133333    0.000000
# 75%      0.136118    0.376278              0.234095    0.333333    1.000000
# max      1.000000    1.000000              1.000000    1.000000    1.000000

# %%
#from matplotlib import pyplot as plt
plt.figure(figsize=(16,6))
ax = sns.boxplot(data = df_normalizado)

# %%
# 1. Primeiro, crie uma cópia do DataFrame original para trabalhar
df_processed = df.copy()

# 2. Defina as colunas para cada tipo de transformação (usando os nomes ORIGINAIS)
colunas_robust = ['Insulina', 'Espessura da pele', 'IMC']
colunas_standard = ['Glicose', 'Pressão arterial']
colunas_passthrough = ['Gravidez', 'Idade']

# 3. Aplique as transformações SEM renomear ainda
transformer = ColumnTransformer(
    transformers=[
        ('robust', RobustScaler(), colunas_robust),
        ('standard', StandardScaler(), colunas_standard),
        ('pass', 'passthrough', colunas_passthrough)
    ],
    remainder='passthrough'
)

# 4. Aplique a transformação
X_transformed = transformer.fit_transform(df_processed)

# 5. Crie o DataFrame transformado mantendo os nomes originais temporariamente
df_padrao_normal = pd.DataFrame(
    X_transformed,
    columns=colunas_robust + colunas_standard + colunas_passthrough + ['Diabetes Descendente', 'Resultado']
)

# 6. AGORA renomeie as colunas (após todas as transformações)
df_padrao_normal = df_padrao_normal.rename(columns={
    'Glicose': 'Glicose_padronizada',
    'Pressão arterial': 'Pressao_padronizada',
    'Insulina': 'Insulina_robusta',
    'Espessura da pele': 'Espessura_pele_robusta',
    'IMC': 'IMC_robusto'
})

# 7. Verifique a ordem final das colunas
print(df_padrao_normal.columns.tolist())
# Out:
# ['Insulina_robusta', 'Espessura_pele_robusta', 'IMC_robusto', 'Glicose_padronizada', 'Pressao_padronizada', 'Gravidez', 'Idade', 'Diabetes Descendente', 'Resultado']

# %%
df_padrao_normal = df_padrao_normal.rename(columns={
    'Glicose': 'Glicose_padronizada',
    'Pressão arterial': 'Pressao_padronizada',
    'Insulina': 'Insulina_robusta',
    'Espessura da pele': 'Espessura_pele_robusta',
    'IMC': 'IMC_robusto'
})

# %%
df_padrao_normal.head()
# Out:
#    Insulina_robusta  Espessura_pele_robusta  IMC_robusto  Glicose_padronizada  \
# 0          0.000000                0.857143     0.142857             0.866045
# 1          0.000000                0.000000    -0.626374            -1.205066
# 2          0.000000                0.000000    -0.989011             2.016662
# 3         -5.391304               -0.857143    -0.461538            -1.073567
# 4          7.478261                0.857143     1.186813             0.504422
#
#    Pressao_padronizada  Gravidez  Idade  Diabetes Descendente  Resultado
# 0            -0.031990       6.0   50.0                 0.627        1.0
# 1            -0.528319       1.0   31.0                 0.351        0.0
# 2            -0.693761       8.0   32.0                 0.672        1.0
# 3            -0.528319       1.0   21.0                 0.167        0.0
# 4            -2.679076       0.0   33.0                 2.288        1.0

# %%
# Visualizando as medidas dos dados normalizados
df_padrao_normal.describe()
# Out:
#        Insulina_robusta  Espessura_pele_robusta  IMC_robusto  \
# count        768.000000              768.000000   768.000000
# mean           2.725543                0.015439     0.017056
# std           15.023141                1.255889     0.755514
# min          -19.304348               -3.142857    -1.549451
# 25%           -0.608696               -0.571429    -0.527473
# 50%            0.000000                0.000000     0.000000
# 75%            0.391304                0.428571     0.472527
# max          125.391304               10.000000     3.824176
#
#        Glicose_padronizada  Pressao_padronizada    Gravidez       Idade  \
# count         7.680000e+02         7.680000e+02  768.000000  768.000000
# mean          4.625929e-18         5.782412e-18    3.845052   33.240885
# std           1.000652e+00         1.000652e+00    3.369578   11.760232
# min          -2.552931e+00        -4.002619e+00    0.000000   21.000000
# 25%          -7.201630e-01        -6.937615e-01    1.000000   24.000000
# 50%          -1.530732e-01        -3.198993e-02    3.000000   29.000000
# 75%           6.112653e-01         6.297816e-01    6.000000   41.000000
# max           2.542658e+00         4.104082e+00   17.000000   81.000000
#
#        Diabetes Descendente   Resultado
# count            768.000000  768.000000
# mean               0.471876    0.348958
# std                0.331329    0.476951
# min                0.078000    0.000000
# 25%                0.243750    0.000000
# 50%                0.372500    0.000000
# 75%                0.626250    1.000000
# max                2.420000    1.000000

# %%
#from matplotlib import pyplot as plt
plt.figure(figsize=(16,6))
ax = sns.boxplot(data = df_padrao_normal)

# %%
df.describe()
# Out:
#          Gravidez     Glicose  Pressão arterial  Espessura da pele  \
# count  768.000000  768.000000        768.000000         768.000000
# mean     3.845052  121.656250         72.386719          29.108073
# std      3.369578   30.438286         12.096642           8.791221
# min      0.000000   44.000000         24.000000           7.000000
# 25%      1.000000   99.750000         64.000000          25.000000
# 50%      3.000000  117.000000         72.000000          29.000000
# 75%      6.000000  140.250000         80.000000          32.000000
# max     17.000000  199.000000        122.000000          99.000000
#
#          Insulina         IMC  Diabetes Descendente       Idade   Resultado
# count  768.000000  768.000000            768.000000  768.000000  768.000000
# mean   140.671875   32.455208              0.471876   33.240885    0.348958
# std     86.383060    6.875177              0.331329   11.760232    0.476951
# min     14.000000   18.200000              0.078000   21.000000    0.000000
# 25%    121.500000   27.500000              0.243750   24.000000    0.000000
# 50%    125.000000   32.300000              0.372500   29.000000    0.000000
# 75%    127.250000   36.600000              0.626250   41.000000    1.000000
# max    846.000000   67.100000              2.420000   81.000000    1.000000

# %% [markdown]
# ## Checklist de Experimentos
# - [ ] Testar pelo menos 3 modelos (ex: Regressão Logística, Random Forest, SVM)
# - [ ] Usar validação cruzada (sugiro 5 folds)
# - [ ] Comparar métricas:
#   - [ ] Acurácia
#   - [ ] Precisão/Recall (importante para dados desbalanceados)
#   - [ ] AUC-ROC
# - [ ] Anotar tempos de treinamento
# - [ ] Verificar feature importance nos melhores modelos

# %%
# Suponha que 'df' seja seu DataFrame completo e 'target' a coluna alvo
X = df.drop('Resultado', axis=1)
y = df['Resultado']

# %%
# Divisão em Dados de Treino e Teste.
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# 1. Regressão Logística
modelo_lr = LogisticRegression()
modelo_lr.fit(X_treino, y_treino)
y_pred_lr = modelo_lr.predict(X_teste)

# %%
# 2. Random Forest
modelo_rf = RandomForestClassifier()
modelo_rf.fit(X_treino, y_treino)
y_pred_rf = modelo_rf.predict(X_teste)

# %%
# 3. Support Vector Machine
modelo_svm = SVC()
modelo_svm.fit(X_treino, y_treino)
y_pred_svm = modelo_svm.predict(X_teste)

# %%
# 4. Árvore de Decisão
modelo_dt = DecisionTreeClassifier()
modelo_dt.fit(X_treino, y_treino)
y_pred_dt = modelo_dt.predict(X_teste)

# %%
# Avaliação dos modelos
modelos = {
    "Regressão Logística": y_pred_lr,
    "Random Forest": y_pred_rf,
    "SVM": y_pred_svm,
    "Árvore de Decisão": y_pred_dt
}

# %%
for nome, y_pred in modelos.items():
    print(f"\nModelo: {nome}")
    print("Acurácia:", accuracy_score(y_teste, y_pred))
    print("Matriz de Confusão:\n", confusion_matrix(y_teste, y_pred))
    print("Relatório de Classificação:\n", classification_report(y_teste, y_pred))
# Out:
# Modelo: Regressão Logística
# Acurácia: 0.7445887445887446
# Matriz de Confusão:
#  [[124  27]
#  [ 32  48]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81       151
#            1       0.64      0.60      0.62        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231
#
#
# Modelo: Random Forest
# Acurácia: 0.7532467532467533
# Matriz de Confusão:
#  [[121  30]
#  [ 27  53]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81       151
#            1       0.64      0.66      0.65        80
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.73      0.73       231
# weighted avg       0.76      0.75      0.75       231
#
#
# Modelo: SVM
# Acurácia: 0.7402597402597403
# Matriz de Confusão:
#  [[131  20]
#  [ 40  40]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.77      0.87      0.81       151
#            1       0.67      0.50      0.57        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.68      0.69       231
# weighted avg       0.73      0.74      0.73       231
#
#
# Modelo: Árvore de Decisão
# Acurácia: 0.6883116883116883
# Matriz de Confusão:
#  [[107  44]
#  [ 28  52]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75       151
#            1       0.54      0.65      0.59        80
#
#     accuracy                           0.69       231
#    macro avg       0.67      0.68      0.67       231
# weighted avg       0.71      0.69      0.69       231

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tabulate import tabulate

# Configuração dos testes
dataframes = {
    'Original': df,
    'Padronizado': df_padronizado,
    'Normalizado': df_normalizado,
    'Misto': df_padrao_normal
}

modelos = {
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': LogisticRegression(max_iter=1000),
    'SVM': SVC(),
    'DecisionTree': DecisionTreeClassifier()
}

# Lista para armazenar resultados
resultados = []

for df_name, dataframe in dataframes.items():
    X = dataframe.drop('Resultado', axis=1)
    y = dataframe['Resultado']
    X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, random_state=42)

    for nome_modelo, modelo in modelos.items():
        try:
            modelo.fit(X_treino, y_treino)
            y_pred = modelo.predict(X_teste)
            
            # Garantindo que as classes são tratadas como strings
            report = classification_report(y_teste, y_pred, output_dict=True, zero_division=0)
            classes = sorted([k for k in report.keys() if k not in ['accuracy', 'macro avg', 'weighted avg']])
            
            # Coletando métricas de forma segura
            metricas = {
                'DataFrame': df_name,
                'Modelo': nome_modelo,
                'Acurácia': accuracy_score(y_teste, y_pred),
                'Matriz': confusion_matrix(y_teste, y_pred)
            }
            
            # Adicionando métricas por classe (adaptável a qualquer número de classes)
            for i, cls in enumerate(classes):
                metricas.update({
                    f'Precision_{i}': report[cls]['precision'],
                    f'Recall_{i}': report[cls]['recall'],
                    f'F1_{i}': report[cls]['f1-score']
                })
            
            resultados.append(metricas)
            
        except Exception as e:
            print(f"Erro em {df_name}/{nome_modelo}: {str(e)}")
            continue

# Exibindo resultados no formato desejado
print("\nRESUMO COMPARATIVO DE MODELOS")
print(tabulate(
    pd.DataFrame(resultados).drop('Matriz', axis=1),
    headers='keys',
    tablefmt='grid',
    floatfmt=".3f",
    showindex=False
))

print("\n\nMATRIZES DE CONFUSÃO DETALHADAS")
for res in resultados:
    print(f"\n{res['DataFrame']} | {res['Modelo']}")
    print(res['Matriz'])
# Out:
# RESUMO COMPARATIVO DE MODELOS
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | DataFrame   | Modelo             |   Acurácia |   Precision_0 |   Recall_0 |   F1_0 |   Precision_1 |   Recall_1 |   F1_1 |
# +=============+====================+============+===============+============+========+===============+============+========+
# | Original    | RandomForest       |      0.745 |         0.811 |      0.795 |  0.803 |         0.627 |      0.650 |  0.638 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Original    | LogisticRegression |      0.740 |         0.790 |      0.821 |  0.805 |         0.635 |      0.588 |  0.610 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Original    | SVM                |      0.740 |         0.766 |      0.868 |  0.814 |         0.667 |      0.500 |  0.571 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Original    | DecisionTree       |      0.688 |         0.788 |      0.715 |  0.750 |         0.543 |      0.637 |  0.586 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Padronizado | RandomForest       |      0.762 |         0.829 |      0.801 |  0.815 |         0.647 |      0.688 |  0.667 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Padronizado | LogisticRegression |      0.740 |         0.790 |      0.821 |  0.805 |         0.635 |      0.588 |  0.610 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Padronizado | SVM                |      0.745 |         0.787 |      0.834 |  0.810 |         0.648 |      0.575 |  0.609 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Padronizado | DecisionTree       |      0.701 |         0.793 |      0.735 |  0.763 |         0.560 |      0.637 |  0.596 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Normalizado | RandomForest       |      0.745 |         0.819 |      0.781 |  0.800 |         0.621 |      0.675 |  0.647 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Normalizado | LogisticRegression |      0.740 |         0.783 |      0.834 |  0.808 |         0.643 |      0.562 |  0.600 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Normalizado | SVM                |      0.740 |         0.786 |      0.828 |  0.806 |         0.639 |      0.575 |  0.605 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Normalizado | DecisionTree       |      0.697 |         0.787 |      0.735 |  0.760 |         0.556 |      0.625 |  0.588 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Misto       | RandomForest       |      0.758 |         0.819 |      0.808 |  0.813 |         0.646 |      0.662 |  0.654 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Misto       | LogisticRegression |      0.740 |         0.790 |      0.821 |  0.805 |         0.635 |      0.588 |  0.610 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Misto       | SVM                |      0.723 |         0.743 |      0.881 |  0.806 |         0.654 |      0.425 |  0.515 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
# | Misto       | DecisionTree       |      0.675 |         0.768 |      0.722 |  0.744 |         0.528 |      0.588 |  0.556 |
# +-------------+--------------------+------------+---------------+------------+--------+---------------+------------+--------+
#
#
# MATRIZES DE CONFUSÃO DETALHADAS
#
# Original | RandomForest
# [[120  31]
#  [ 28  52]]
#
# Original | LogisticRegression
# [[124  27]
#  [ 33  47]]
#
# Original | SVM
# [[131  20]
#  [ 40  40]]
#
# Original | DecisionTree
# [[108  43]
#  [ 29  51]]
#
# Padronizado | RandomForest
# [[121  30]
#  [ 25  55]]
#
# Padronizado | LogisticRegression
# [[124  27]
#  [ 33  47]]
#
# Padronizado | SVM
# [[126  25]
#  [ 34  46]]
#
# Padronizado | DecisionTree
# [[111  40]
#  [ 29  51]]
#
# Normalizado | RandomForest
# [[118  33]
#  [ 26  54]]
#
# Normalizado | LogisticRegression
# [[126  25]
#  [ 35  45]]
#
# Normalizado | SVM
# [[125  26]
#  [ 34  46]]
#
# Normalizado | DecisionTree
# [[111  40]
#  [ 30  50]]
#
# Misto | RandomForest
# [[122  29]
#  [ 27  53]]
#
# Misto | LogisticRegression
# [[124  27]
#  [ 33  47]]
#
# Misto | SVM
# [[133  18]
#  [ 46  34]]
#
# Misto | DecisionTree
# [[109  42]
#  [ 33  47]]

# %%
modelos = {
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': LogisticRegression(),
    'SVM': SVC(),
    'DecisionTreeClassifier': DecisionTreeClassifier()
}

for df_name, dataframe in [('Original', df),
                          ('Padronizado', df_padronizado), 
                          ('Normalizado', df_normalizado),
                          ('Misto', df_padrao_normal)]:
    X = dataframe.drop('Resultado', axis=1)
    y = dataframe['Resultado']
    X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 42)

    for nome, modelo in modelos.items():
        modelo_ax = modelo
        modelo_ax.fit(X_treino, y_treino)
        y_pred_ax = modelo_dt.predict(X_teste)
        
        print(f"\nData Frame: {df_name}")
        print(f"Modelo: {nome}")
        print("Acurácia:", accuracy_score(y_teste, y_pred))
        print("Matriz de Confusão:\n", confusion_matrix(y_teste, y_pred))
        print("Relatório de Classificação:\n", classification_report(y_teste, y_pred))
        print("-" * 30)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

modelos = {
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': LogisticRegression(),
    'SVM': SVC()
}

for nome, modelo in modelos.items():
    for df_name, dataframe in [('Padronizado', df_padronizado), 
                              ('Normalizado', df_normalizado),
                              ('Corrigido', df_padrao_normal)]:
        scores = cross_val_score(modelo, dataframe.drop('Resultado', axis=1), 
                               dataframe['Resultado'], cv=5)
        print(f"{nome} no {df_name}: Acurácia média {scores.mean():.2f} (+/- {scores.std():.2f})")
